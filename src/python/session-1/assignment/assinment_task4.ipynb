# %%
def extract_core(message):
    """Keep only letters and spaces, drop the junk around them."""
    core = ""
    for ch in message:
        if ch.isalpha() or ch == " ":
            core = core + ch
    return core.strip()


def reverse_word(word):
    """Reverse a word: 'yalpstcejorp' -> 'projectsplay'"""
    return word[::-1]


def replace_shifted_vowels(word):
    """Replace the shifted vowels: E -> A and U -> O."""
    vowel_map = {"E": "A", "U": "O"}

    result = ""
    for ch in word:
        if ch in vowel_map:
            result = result + vowel_map[ch]
        else:
            result = result + ch
    return result


def decode_message(message):
    core = extract_core(message)                    # step 1
    words = core.split(" ")

    first_word = reverse_word(words[0])             # step 2
    second_word = replace_shifted_vowels(words[1])  # step 3

    return first_word + " " + second_word           # step 4

# %%
encoded = "##$$$@!yalpstcejorp EPUVT****9887"

print("Encoded:", encoded)
print("Core:   ", extract_core(encoded))
print("Decoded:", decode_message(encoded))
# Out:
# Encoded: ##$$$@!yalpstcejorp EPUVT****9887
# Core:    yalpstcejorp EPUVT
# Decoded: projectsplay APOVT
