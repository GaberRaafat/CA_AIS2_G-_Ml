# %% [markdown]
# Description:
# Complete the solution so that it reverses all of the words within the string passed in.
#
# Words are separated by exactly one space and there are no leading or trailing spaces.
#
# Example(Input --> Output):
#
# "The greatest victory is that which requires no battle" --> "battle no requires which that is victory greatest The"

# %%
def reverse_words(text):
    words = text.split(" ")   # break the sentence into a list of words
    words.reverse()           # flip the list around
    return " ".join(words)    # glue them back together with spaces

print(reverse_words("The greatest victory is that which requires no battle"))
